# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  'data_loader',
#  'data_processor',
#  'jupyter',
#  'loggers',
#  'main.py',
#  'models',
#  'original_data',
#  'processed_data',
#  'README.md',
#  'requirements.txt',
#  'saved_models',
#  'tests',
#  'trainers']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MLP import MLP
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
data_train, data_val = load_numpy_arrays(['data_train.npy', 'data_val.npy'], 
                                            path_prefix='processed_data/processed_features/10-genres/')

# %%
X_train, y_train = data_train[:, :-1], data_train[:, -1]
X_val, y_val = data_val[:, :-1], data_val[:, -1]

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([800, 57])
# torch.Size([800])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([ 0.4430,  0.7689,  1.1854,  0.9865,  1.1729,  2.2850,  1.5993,  0.5470,
#          1.2933,  1.4533,  0.3579,  1.6253,  0.2378,  0.9808,  0.3478,  1.0291,
#          0.8722,  0.6536,  0.1507, -1.0807,  0.9324,  1.5295,  1.6476, -0.6216,
#          1.2637,  1.2384,  0.5888, -0.9140,  2.3868,  2.1714,  1.2330, -0.8752,
#          1.5690,  1.2485,  0.6235, -0.4043,  0.5381,  1.3089,  0.5665, -0.1021,
#          0.4306,  1.0201, -0.0346,  0.0734,  0.1968,  0.4319, -0.1783, -1.0909,
#         -0.1586,  0.6607, -0.2541, -0.3802, -0.1895,  0.4879, -0.3387,  0.0709,
#         -0.0540])
# tensor(7)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([100, 57])
# torch.Size([100])

# %%
# define a model instance
# eg. MLP

model = MLP(57, 10, [100])

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.01
batch_size = 100
num_epoch = 20
model_name = 'MLP'
saved_model_name = 'saved_models/saved_' + model_name + '_csv.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train, y_train, X_val, y_val), 
                                                                                                                            loss, optimizer, batch_size=batch_size, num_epoch=num_epoch, saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 1.4159
# training accuracy: 52.25% validation accuracy: 54.00%
# Epoch  1: loss on final training batch: 1.0572
# training accuracy: 65.38% validation accuracy: 64.00%
# Epoch  2: loss on final training batch: 0.8135
# training accuracy: 74.38% validation accuracy: 68.00%
# Epoch  3: loss on final training batch: 0.6713
# training accuracy: 80.00% validation accuracy: 68.00%
# Epoch  4: loss on final training batch: 0.5337
# training accuracy: 83.88% validation accuracy: 71.00%
# Epoch  5: loss on final training batch: 0.4369
# training accuracy: 88.75% validation accuracy: 73.00%
# Epoch  6: loss on final training batch: 0.3670
# training accuracy: 91.00% validation accuracy: 77.00%
# Epoch  7: loss on final training batch: 0.2980
# training accuracy: 93.00% validation accuracy: 79.00%
# Epoch  8: loss on final training batch: 0.2408
# training accuracy: 94.88% validation accuracy: 80.00%
# Epoch  9: loss on final training batch: 0.1920
# training accuracy: 96.75% validation accuracy: 81.00%
# Epoch 10: loss on final training batch: 0.1614
# training accuracy: 97.62% validation accuracy: 80.00%
# Epoch 11: loss on final training batch: 0.1320
# training accuracy: 99.00% validation accuracy: 80.00%
# Epoch 12: loss on final training batch: 0.1043
# training accuracy: 99.62% validation accuracy: 79.00%
# Epoch 13: loss on final training batch: 0.0872
# training accuracy: 99.62% validation accuracy: 80.00%
# Epoch 14: loss on final training batch: 0.0729
# training accuracy: 99.88% validation accuracy: 80.00%
# Epoch 15: loss on final training batch: 0.0605
# training accuracy: 99.88% validation accuracy: 78.00%
# Epoch 16: loss on final training batch: 0.0520
# training accuracy: 99.88% validation accuracy: 78.00%
# Epoch 17: loss on final training batch: 0.0426
# training accuracy: 99.88% validation accuracy: 79.00%
# Epoch 18: loss on final training batch: 0.0372
# training accuracy: 99.88% validation accuracy: 79.00%
# Epoch 19: loss on final training batch: 0.0335
# training accuracy: 99.88% validation accuracy: 79.00%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
