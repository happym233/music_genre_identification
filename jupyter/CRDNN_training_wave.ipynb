# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %% [markdown]
# ## switch to the root dir

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicCRDNN import MusicCRDNN
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([2390, 501, 40])
# torch.Size([2390])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[ 0.4324,  0.5236,  0.5394,  ...,  0.7697,  0.7055,  0.3866],
#         [ 0.7034,  0.6647,  0.4897,  ...,  0.4557,  0.3747,  0.2816],
#         [ 0.6879,  0.5071,  0.1787,  ...,  0.1181,  0.2188,  0.3338],
#         ...,
#         [ 0.9628,  0.9904,  0.9130,  ...,  0.3897,  0.3010,  0.0407],
#         [ 0.8118,  0.8570,  0.7527,  ...,  0.1811,  0.2039, -0.0195],
#         [ 0.4746,  0.5449,  0.4947,  ..., -0.2057, -0.4388, -0.4447]])
# tensor(0)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([299, 501, 40])
# torch.Size([299])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicCRDNN([8, 32, 64, 64], 10, 128, 256, 5, [60])

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
X_a = X_train[:10].reshape((-1, 1, n_time, n_feat))
pred = model(X_a)

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 200
num_epoch = 200
model_name = 'CRNN'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
X_train_2d = X_train.reshape((-1, 1, n_time, n_feat))
print(X_train.shape)
X_val_2d = X_val.reshape((-1, 1, n_time, n_feat))
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train_2d, y_train, X_val_2d, y_val), loss, optimizer, batch_size=batch_size, num_epoch=num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# torch.Size([2390, 501, 40])
# Epoch  0: loss on final training batch: 2.1497
# training accuracy: 18.95% validation accuracy: 13.04%
# Epoch  1: loss on final training batch: 1.9863
# training accuracy: 31.84% validation accuracy: 32.78%
# Epoch  2: loss on final training batch: 1.7108
# training accuracy: 36.86% validation accuracy: 37.79%
# Epoch  3: loss on final training batch: 1.5843
# training accuracy: 44.10% validation accuracy: 45.48%
# Epoch  4: loss on final training batch: 1.4170
# training accuracy: 50.46% validation accuracy: 44.15%
# Epoch  5: loss on final training batch: 1.2967
# training accuracy: 52.59% validation accuracy: 49.83%
# Epoch  6: loss on final training batch: 1.2233
# training accuracy: 58.24% validation accuracy: 60.54%
# Epoch  7: loss on final training batch: 1.2325
# training accuracy: 58.20% validation accuracy: 54.85%
# Epoch  8: loss on final training batch: 1.1338
# training accuracy: 63.10% validation accuracy: 59.20%
# Epoch  9: loss on final training batch: 0.9742
# training accuracy: 67.36% validation accuracy: 62.88%
# Epoch 10: loss on final training batch: 0.9505
# training accuracy: 69.83% validation accuracy: 66.89%
# Epoch 11: loss on final training batch: 0.7998
# training accuracy: 72.72% validation accuracy: 71.57%
# Epoch 12: loss on final training batch: 0.7866
# training accuracy: 76.11% validation accuracy: 72.58%
# Epoch 13: loss on final training batch: 0.8708
# training accuracy: 74.60% validation accuracy: 71.91%
# Epoch 14: loss on final training batch: 0.6319
# training accuracy: 78.66% validation accuracy: 76.59%
# Epoch 15: loss on final training batch: 0.6099
# training accuracy: 82.51% validation accuracy: 76.59%
# Epoch 16: loss on final training batch: 0.6311
# training accuracy: 81.97% validation accuracy: 75.92%
# Epoch 17: loss on final training batch: 0.6545
# training accuracy: 81.21% validation accuracy: 75.25%
# Epoch 18: loss on final training batch: 0.5158
# training accuracy: 83.81% validation accuracy: 73.58%
# Epoch 19: loss on final training batch: 0.4571
# training accuracy: 85.23% validation accuracy: 80.60%
# Epoch 20: loss on final training batch: 0.5632
# training accuracy: 80.29% validation accuracy: 75.92%
# Epoch 21: loss on final training batch: 0.4399
# training accuracy: 85.40% validation accuracy: 80.27%
# Epoch 22: loss on final training batch: 0.4214
# training accuracy: 86.65% validation accuracy: 80.94%
# Epoch 23: loss on final training batch: 0.4308
# training accuracy: 88.87% validation accuracy: 80.27%
# Epoch 24: loss on final training batch: 0.4013
# training accuracy: 88.24% validation accuracy: 80.60%
# Epoch 25: loss on final training batch: 0.3446
# training accuracy: 88.12% validation accuracy: 75.92%
# Epoch 26: loss on final training batch: 0.3156
# training accuracy: 89.96% validation accuracy: 76.25%
# Epoch 27: loss on final training batch: 0.4846
# training accuracy: 83.35% validation accuracy: 74.92%
# Epoch 28: loss on final training batch: 0.2949
# training accuracy: 88.08% validation accuracy: 77.93%
# Epoch 29: loss on final training batch: 0.3000
# training accuracy: 90.88% validation accuracy: 78.26%
# Epoch 30: loss on final training batch: 0.3623
# training accuracy: 91.51% validation accuracy: 81.61%
# Epoch 31: loss on final training batch: 0.2695
# training accuracy: 92.76% validation accuracy: 82.61%
# Epoch 32: loss on final training batch: 0.2921
# training accuracy: 92.38% validation accuracy: 76.92%
# Epoch 33: loss on final training batch: 0.2380
# training accuracy: 91.13% validation accuracy: 79.93%
# Epoch 34: loss on final training batch: 0.2761
# training accuracy: 92.18% validation accuracy: 79.93%
# Epoch 35: loss on final training batch: 0.2745
# training accuracy: 91.97% validation accuracy: 77.26%
# Epoch 36: loss on final training batch: 0.1865
# training accuracy: 92.89% validation accuracy: 77.59%
# Epoch 37: loss on final training batch: 0.2299
# training accuracy: 91.72% validation accuracy: 78.60%
# Epoch 38: loss on final training batch: 0.2510
# training accuracy: 94.02% validation accuracy: 81.27%
# Epoch 39: loss on final training batch: 0.1623
# training accuracy: 95.36% validation accuracy: 82.94%
# Epoch 40: loss on final training batch: 0.1259
# training accuracy: 96.65% validation accuracy: 82.61%
# Epoch 41: loss on final training batch: 0.2794
# training accuracy: 96.57% validation accuracy: 81.27%
# Epoch 42: loss on final training batch: 0.1601
# training accuracy: 97.74% validation accuracy: 79.26%
# Epoch 43: loss on final training batch: 0.1314
# training accuracy: 97.11% validation accuracy: 83.95%
# Epoch 44: loss on final training batch: 0.1436
# training accuracy: 95.27% validation accuracy: 80.27%
# Epoch 45: loss on final training batch: 0.0713
# training accuracy: 98.49% validation accuracy: 80.94%
# Epoch 46: loss on final training batch: 0.0582
# training accuracy: 98.91% validation accuracy: 80.27%
# Epoch 47: loss on final training batch: 0.0757
# training accuracy: 98.95% validation accuracy: 83.61%
# Epoch 48: loss on final training batch: 0.0527
# training accuracy: 99.21% validation accuracy: 80.94%
# Epoch 49: loss on final training batch: 0.0664
# training accuracy: 98.20% validation accuracy: 81.94%
# Epoch 50: loss on final training batch: 0.0456
# training accuracy: 98.37% validation accuracy: 81.61%
# Epoch 51: loss on final training batch: 0.0395
# training accuracy: 98.95% validation accuracy: 82.27%
# Epoch 52: loss on final training batch: 0.0434
# training accuracy: 99.04% validation accuracy: 82.61%
# Epoch 53: loss on final training batch: 0.0414
# training accuracy: 98.87% validation accuracy: 83.28%
# Epoch 54: loss on final training batch: 0.0873
# training accuracy: 98.79% validation accuracy: 83.28%
# Epoch 55: loss on final training batch: 0.0479
# training accuracy: 99.37% validation accuracy: 82.94%
# Epoch 56: loss on final training batch: 0.0417
# training accuracy: 99.54% validation accuracy: 82.61%
# Epoch 57: loss on final training batch: 0.0400
# training accuracy: 99.37% validation accuracy: 81.27%
# Epoch 58: loss on final training batch: 0.1455
# training accuracy: 97.24% validation accuracy: 82.94%
# Epoch 59: loss on final training batch: 0.0530
# training accuracy: 98.03% validation accuracy: 81.27%
# Epoch 60: loss on final training batch: 0.0628
# training accuracy: 98.95% validation accuracy: 80.60%
# Epoch 61: loss on final training batch: 0.0818
# training accuracy: 98.58% validation accuracy: 81.61%
# Epoch 62: loss on final training batch: 0.0812
# training accuracy: 97.91% validation accuracy: 81.94%
# Epoch 63: loss on final training batch: 0.0824
# training accuracy: 98.49% validation accuracy: 83.61%
# Epoch 64: loss on final training batch: 0.0631
# training accuracy: 98.87% validation accuracy: 80.94%
# Epoch 65: loss on final training batch: 0.0688
# training accuracy: 98.66% validation accuracy: 83.95%
# Epoch 66: loss on final training batch: 0.0380
# training accuracy: 99.04% validation accuracy: 83.95%
# Epoch 67: loss on final training batch: 0.0707
# training accuracy: 98.95% validation accuracy: 80.60%
# Epoch 68: loss on final training batch: 0.0588
# training accuracy: 99.37% validation accuracy: 83.95%
# Epoch 69: loss on final training batch: 0.0466
# training accuracy: 99.46% validation accuracy: 82.61%
# Epoch 70: loss on final training batch: 0.0314
# training accuracy: 99.54% validation accuracy: 83.28%
# Epoch 71: loss on final training batch: 0.0432
# training accuracy: 99.75% validation accuracy: 83.28%
# Epoch 72: loss on final training batch: 0.0232
# training accuracy: 99.71% validation accuracy: 83.28%
# Epoch 73: loss on final training batch: 0.0134
# training accuracy: 99.75% validation accuracy: 82.94%
# Epoch 74: loss on final training batch: 0.0027
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 75: loss on final training batch: 0.0020
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 76: loss on final training batch: 0.0019
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 77: loss on final training batch: 0.0017
# training accuracy: 99.92% validation accuracy: 83.61%
# Epoch 78: loss on final training batch: 0.0016
# training accuracy: 99.92% validation accuracy: 83.61%
# Epoch 79: loss on final training batch: 0.0015
# training accuracy: 99.92% validation accuracy: 83.61%
# Epoch 80: loss on final training batch: 0.0014
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 81: loss on final training batch: 0.0013
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 82: loss on final training batch: 0.0013
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 83: loss on final training batch: 0.0012
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 84: loss on final training batch: 0.0011
# training accuracy: 99.92% validation accuracy: 83.28%
# Epoch 85: loss on final training batch: 0.0012
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 86: loss on final training batch: 0.0011
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 87: loss on final training batch: 0.0011
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 88: loss on final training batch: 0.0010
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 89: loss on final training batch: 0.0010
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 90: loss on final training batch: 0.0010
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 91: loss on final training batch: 0.0009
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 92: loss on final training batch: 0.0008
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 93: loss on final training batch: 0.0008
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 94: loss on final training batch: 0.0008
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 95: loss on final training batch: 0.0009
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 96: loss on final training batch: 0.0007
# training accuracy: 99.96% validation accuracy: 84.95%
# Epoch 97: loss on final training batch: 0.0007
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 98: loss on final training batch: 0.0007
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 99: loss on final training batch: 0.0007
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 100: loss on final training batch: 0.0007
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 101: loss on final training batch: 0.0007
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 102: loss on final training batch: 0.0007
# training accuracy: 99.87% validation accuracy: 85.62%
# Epoch 103: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 85.95%
# Epoch 104: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 105: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 106: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 107: loss on final training batch: 0.0044
# training accuracy: 99.79% validation accuracy: 83.28%
# Epoch 108: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 109: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 110: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 111: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 112: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 113: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 114: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 115: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 116: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 117: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 118: loss on final training batch: 0.0005
# training accuracy: 99.96% validation accuracy: 84.95%
# Epoch 119: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 120: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 121: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 122: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 123: loss on final training batch: 0.0004
# training accuracy: 99.87% validation accuracy: 84.62%
# Epoch 124: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 125: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.95%
# Epoch 126: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 127: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 128: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 129: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 130: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 131: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 132: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 133: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 134: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 135: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 136: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 137: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 138: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 139: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 140: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 141: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 142: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.95%
# Epoch 143: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 144: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 145: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 146: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 147: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 148: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 149: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 150: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 151: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 152: loss on final training batch: 0.0002
# training accuracy: 99.87% validation accuracy: 85.95%
# Epoch 153: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 154: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 155: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 156: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 157: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 158: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 159: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 160: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 161: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 162: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 163: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.62%
# Epoch 164: loss on final training batch: 0.0002
# training accuracy: 99.87% validation accuracy: 84.95%
# Epoch 165: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 166: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 167: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 168: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.28%
# Epoch 169: loss on final training batch: 0.0002
# training accuracy: 99.92% validation accuracy: 85.62%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
