# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %% [markdown]
# ## switch to the root dir

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicCRDNN import MusicCRDNN
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([2390, 501, 40])
# torch.Size([2390])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[ 0.4324,  0.5236,  0.5394,  ...,  0.7697,  0.7055,  0.3866],
#         [ 0.7034,  0.6647,  0.4897,  ...,  0.4557,  0.3747,  0.2816],
#         [ 0.6879,  0.5071,  0.1787,  ...,  0.1181,  0.2188,  0.3338],
#         ...,
#         [ 0.9628,  0.9904,  0.9130,  ...,  0.3897,  0.3010,  0.0407],
#         [ 0.8118,  0.8570,  0.7527,  ...,  0.1811,  0.2039, -0.0195],
#         [ 0.4746,  0.5449,  0.4947,  ..., -0.2057, -0.4388, -0.4447]])
# tensor(0)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([299, 501, 40])
# torch.Size([299])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicCRDNN([8, 32, 64, 64], 10, 128, 128, 4, [80], False, True)

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
X_a = X_train[:10].reshape((-1, 1, n_time, n_feat))
pred = model(X_a)

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 150
num_epoch = 100
model_name = 'CRNN_bidirectional'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
X_train_2d = X_train.reshape((-1, 1, n_time, n_feat))
print(X_train.shape)
X_val_2d = X_val.reshape((-1, 1, n_time, n_feat))
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train_2d, y_train, X_val_2d, y_val), loss, optimizer, batch_size=batch_size, num_epoch=num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# torch.Size([2390, 501, 40])
# Epoch  0: loss on final training batch: 1.9272
# training accuracy: 31.17% validation accuracy: 26.76%
# Epoch  1: loss on final training batch: 1.7960
# training accuracy: 41.76% validation accuracy: 34.78%
# Epoch  2: loss on final training batch: 1.5528
# training accuracy: 49.79% validation accuracy: 44.48%
# Epoch  3: loss on final training batch: 1.4266
# training accuracy: 55.82% validation accuracy: 53.85%
# Epoch  4: loss on final training batch: 1.2710
# training accuracy: 60.71% validation accuracy: 59.20%
# Epoch  5: loss on final training batch: 1.0732
# training accuracy: 63.26% validation accuracy: 58.86%
# Epoch  6: loss on final training batch: 1.1496
# training accuracy: 65.73% validation accuracy: 61.87%
# Epoch  7: loss on final training batch: 0.9366
# training accuracy: 72.47% validation accuracy: 68.23%
# Epoch  8: loss on final training batch: 0.8537
# training accuracy: 74.10% validation accuracy: 68.90%
# Epoch  9: loss on final training batch: 0.7679
# training accuracy: 77.24% validation accuracy: 71.91%
# Epoch 10: loss on final training batch: 0.7136
# training accuracy: 77.82% validation accuracy: 71.91%
# Epoch 11: loss on final training batch: 0.7195
# training accuracy: 78.83% validation accuracy: 70.57%
# Epoch 12: loss on final training batch: 0.5100
# training accuracy: 83.56% validation accuracy: 76.59%
# Epoch 13: loss on final training batch: 0.6029
# training accuracy: 81.13% validation accuracy: 72.58%
# Epoch 14: loss on final training batch: 0.3724
# training accuracy: 86.90% validation accuracy: 77.59%
# Epoch 15: loss on final training batch: 0.4712
# training accuracy: 84.73% validation accuracy: 75.25%
# Epoch 16: loss on final training batch: 0.3121
# training accuracy: 87.57% validation accuracy: 77.59%
# Epoch 17: loss on final training batch: 0.3873
# training accuracy: 85.61% validation accuracy: 75.92%
# Epoch 18: loss on final training batch: 0.4801
# training accuracy: 85.77% validation accuracy: 77.26%
# Epoch 19: loss on final training batch: 0.4039
# training accuracy: 87.53% validation accuracy: 75.92%
# Epoch 20: loss on final training batch: 0.2519
# training accuracy: 89.75% validation accuracy: 77.59%
# Epoch 21: loss on final training batch: 0.3080
# training accuracy: 90.79% validation accuracy: 79.60%
# Epoch 22: loss on final training batch: 0.4817
# training accuracy: 90.63% validation accuracy: 75.59%
# Epoch 23: loss on final training batch: 0.3205
# training accuracy: 89.58% validation accuracy: 75.59%
# Epoch 24: loss on final training batch: 0.1870
# training accuracy: 90.84% validation accuracy: 78.60%
# Epoch 25: loss on final training batch: 0.3219
# training accuracy: 91.51% validation accuracy: 76.59%
# Epoch 26: loss on final training batch: 0.1255
# training accuracy: 94.98% validation accuracy: 79.60%
# Epoch 27: loss on final training batch: 0.2137
# training accuracy: 91.21% validation accuracy: 75.25%
# Epoch 28: loss on final training batch: 0.2397
# training accuracy: 91.97% validation accuracy: 78.60%
# Epoch 29: loss on final training batch: 0.1751
# training accuracy: 93.35% validation accuracy: 78.60%
# Epoch 30: loss on final training batch: 0.1868
# training accuracy: 93.85% validation accuracy: 80.60%
# Epoch 31: loss on final training batch: 0.1120
# training accuracy: 96.61% validation accuracy: 80.27%
# Epoch 32: loss on final training batch: 0.0608
# training accuracy: 96.90% validation accuracy: 82.61%
# Epoch 33: loss on final training batch: 0.1653
# training accuracy: 96.90% validation accuracy: 82.27%
# Epoch 34: loss on final training batch: 0.1005
# training accuracy: 96.57% validation accuracy: 83.95%
# Epoch 35: loss on final training batch: 0.0820
# training accuracy: 97.78% validation accuracy: 84.28%
# Epoch 36: loss on final training batch: 0.0546
# training accuracy: 97.95% validation accuracy: 83.95%
# Epoch 37: loss on final training batch: 0.1035
# training accuracy: 97.99% validation accuracy: 81.27%
# Epoch 38: loss on final training batch: 0.0869
# training accuracy: 98.03% validation accuracy: 80.94%
# Epoch 39: loss on final training batch: 0.0840
# training accuracy: 98.79% validation accuracy: 83.61%
# Epoch 40: loss on final training batch: 0.0114
# training accuracy: 98.41% validation accuracy: 82.94%
# Epoch 41: loss on final training batch: 0.0122
# training accuracy: 99.29% validation accuracy: 85.28%
# Epoch 42: loss on final training batch: 0.0168
# training accuracy: 98.95% validation accuracy: 82.61%
# Epoch 43: loss on final training batch: 0.0053
# training accuracy: 99.12% validation accuracy: 83.28%
# Epoch 44: loss on final training batch: 0.1012
# training accuracy: 97.41% validation accuracy: 81.61%
# Epoch 45: loss on final training batch: 0.0131
# training accuracy: 98.70% validation accuracy: 81.94%
# Epoch 46: loss on final training batch: 0.0117
# training accuracy: 98.16% validation accuracy: 82.61%
# Epoch 47: loss on final training batch: 0.0734
# training accuracy: 97.28% validation accuracy: 80.60%
# Epoch 48: loss on final training batch: 0.0653
# training accuracy: 98.95% validation accuracy: 84.95%
# Epoch 49: loss on final training batch: 0.0902
# training accuracy: 96.44% validation accuracy: 80.60%
# Epoch 50: loss on final training batch: 0.0499
# training accuracy: 96.69% validation accuracy: 81.94%
# Epoch 51: loss on final training batch: 0.0992
# training accuracy: 96.11% validation accuracy: 78.60%
# Epoch 52: loss on final training batch: 0.0390
# training accuracy: 98.33% validation accuracy: 80.60%
# Epoch 53: loss on final training batch: 0.0103
# training accuracy: 97.95% validation accuracy: 77.93%
# Epoch 54: loss on final training batch: 0.0083
# training accuracy: 99.37% validation accuracy: 84.28%
# Epoch 55: loss on final training batch: 0.0034
# training accuracy: 99.71% validation accuracy: 83.61%
# Epoch 56: loss on final training batch: 0.0031
# training accuracy: 99.58% validation accuracy: 84.95%
# Epoch 57: loss on final training batch: 0.0018
# training accuracy: 99.67% validation accuracy: 85.28%
# Epoch 58: loss on final training batch: 0.0014
# training accuracy: 99.71% validation accuracy: 84.95%
# Epoch 59: loss on final training batch: 0.0013
# training accuracy: 99.83% validation accuracy: 85.62%
# Epoch 60: loss on final training batch: 0.0013
# training accuracy: 99.79% validation accuracy: 84.95%
# Epoch 61: loss on final training batch: 0.0011
# training accuracy: 99.83% validation accuracy: 84.95%
# Epoch 62: loss on final training batch: 0.0009
# training accuracy: 99.96% validation accuracy: 84.95%
# Epoch 63: loss on final training batch: 0.0009
# training accuracy: 99.87% validation accuracy: 84.62%
# Epoch 64: loss on final training batch: 0.0008
# training accuracy: 99.87% validation accuracy: 84.95%
# Epoch 65: loss on final training batch: 0.0007
# training accuracy: 99.87% validation accuracy: 84.28%
# Epoch 66: loss on final training batch: 0.0007
# training accuracy: 99.92% validation accuracy: 83.95%
# Epoch 67: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 68: loss on final training batch: 0.0006
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 69: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 70: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 71: loss on final training batch: 0.0005
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 72: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 84.62%
# Epoch 73: loss on final training batch: 0.0004
# training accuracy: 99.96% validation accuracy: 84.95%
# Epoch 74: loss on final training batch: 0.0004
# training accuracy: 99.87% validation accuracy: 85.28%
# Epoch 75: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 76: loss on final training batch: 0.0004
# training accuracy: 99.92% validation accuracy: 84.28%
# Epoch 77: loss on final training batch: 0.0003
# training accuracy: 99.87% validation accuracy: 84.28%
# Epoch 78: loss on final training batch: 0.0003
# training accuracy: 99.92% validation accuracy: 84.95%
# Epoch 79: loss on final training batch: 0.0005
# training accuracy: 99.50% validation accuracy: 83.61%
# Epoch 80: loss on final training batch: 0.1972
# training accuracy: 97.78% validation accuracy: 85.28%
# Epoch 81: loss on final training batch: 0.1051
# training accuracy: 96.19% validation accuracy: 79.26%
# Epoch 82: loss on final training batch: 0.1111
# training accuracy: 95.36% validation accuracy: 81.61%
# Epoch 83: loss on final training batch: 0.2444
# training accuracy: 95.77% validation accuracy: 80.94%
# Epoch 84: loss on final training batch: 0.0566
# training accuracy: 97.36% validation accuracy: 82.94%
# Epoch 85: loss on final training batch: 0.0716
# training accuracy: 97.45% validation accuracy: 79.60%
# Epoch 86: loss on final training batch: 0.1062
# training accuracy: 97.11% validation accuracy: 78.93%
# Epoch 87: loss on final training batch: 0.0396
# training accuracy: 98.24% validation accuracy: 81.61%
# Epoch 88: loss on final training batch: 0.0255
# training accuracy: 98.74% validation accuracy: 82.94%
# Epoch 89: loss on final training batch: 0.2430
# training accuracy: 95.69% validation accuracy: 80.27%
# Epoch 90: loss on final training batch: 0.0382
# training accuracy: 97.74% validation accuracy: 83.95%
# Epoch 91: loss on final training batch: 0.0147
# training accuracy: 99.50% validation accuracy: 81.61%
# Epoch 92: loss on final training batch: 0.0178
# training accuracy: 99.54% validation accuracy: 81.94%
# Epoch 93: loss on final training batch: 0.0086
# training accuracy: 99.21% validation accuracy: 83.61%
# Epoch 94: loss on final training batch: 0.0369
# training accuracy: 99.04% validation accuracy: 81.61%
# Epoch 95: loss on final training batch: 0.0391
# training accuracy: 98.62% validation accuracy: 84.62%
# Epoch 96: loss on final training batch: 0.0209
# training accuracy: 99.29% validation accuracy: 83.28%
# Epoch 97: loss on final training batch: 0.0115
# training accuracy: 99.29% validation accuracy: 82.94%
# Epoch 98: loss on final training batch: 0.0034
# training accuracy: 99.83% validation accuracy: 84.95%
# Epoch 99: loss on final training batch: 0.0013
# training accuracy: 99.92% validation accuracy: 84.62%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
