# %%
import os

# %%
os.chdir('..')

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  'data_loader',
#  'data_processor',
#  'jupyter',
#  'loggers',
#  'main.py',
#  'models',
#  'original_data',
#  'processed_data',
#  'README.md',
#  'requirements.txt',
#  'saved_models',
#  'trainers']

# %%
from data_loader.music_wave_loader import get_music_file_names
from data_processor.utils import split_data, normalize_data, FunctionArrayExecutor, save_numpy_arrays, load_numpy_arrays
from data_processor.waves_data_processor import generate_wave_features
from loggers.statistics_loggers import print_stats
import speechbrain as sb
from speechbrain.processing.features import STFT, spectral_magnitude, Filterbank
import torch
import numpy as np
# Out:
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.

# %%
music_name_lists = get_music_file_names('original_data/genres_original/', 
                                        ['rock', 'classical', 'metal', 'disco', 'blues', 'reggae', 'country', 'hiphop', 'jazz', 'pop'])

# %%
#print(music_name_lists)

# %%
compute_STFT = STFT(
    sample_rate=22050, win_length=15, hop_length=20, n_fft=400
)

compute_fbanks = Filterbank(n_mels=40, sample_rate = 22050)

# %%
extract_wave_features = FunctionArrayExecutor([compute_STFT, spectral_magnitude, compute_fbanks])

# %%
features, labels = generate_wave_features(music_name_lists, 10, extract_wave_features, root='original_data/genres_original/')

# %%
print_stats(features)
# Out:
# Shape: (2988, 501, 40)
# Dtype: torch.float32
#  - Max:     39.016
#  - Min:     -70.695
#  - Mean:    -1.979
#  - Std Dev: 13.695
#
# tensor([[[ 7.1592e+00,  5.6211e+00,  5.2819e+00,  ..., -1.5695e+01,
#           -2.1134e+01, -1.8806e+01],
#          [ 5.1370e+00,  5.2218e+00,  7.1488e+00,  ..., -1.3223e+01,
#           -1.1551e+01, -2.0770e+01],
#          [ 7.8673e+00,  9.0765e+00,  7.9763e+00,  ..., -6.0891e+00,
#           -5.5195e+00, -1.5894e+01],
#          ...,
#          [ 9.9964e+00,  6.9721e+00,  4.0837e+00,  ..., -4.2699e+00,
#           -3.5919e+00, -4.2008e+00],
#          [-8.5661e-01,  8.3650e-01,  8.0525e-02,  ...,  5.7160e-01,
#            5.5786e-01, -3.8375e+00],
#          [ 1.0599e+01,  1.1279e+01,  1.0326e+01,  ..., -9.2104e-01,
#           -4.4086e+00, -7.8152e+00]],
#
#         [[ 9.4522e+00,  1.1062e+01,  1.1633e+01,  ...,  2.6631e+00,
#           -1.3678e+00, -1.4419e+00],
#          [-8.6365e-01,  9.6416e+00,  1.2896e+01,  ...,  1.0327e+01,
#            1.3919e+01,  5.5544e+00],
#          [ 4.0896e-01, -6.4569e-01,  9.9277e+00,  ...,  4.2220e+00,
#            2.2101e+00,  3.4223e+00],
#          ...,
#          [ 8.9538e-01,  1.6521e+01,  1.8897e+01,  ..., -1.1944e+00,
#            2.0036e-01, -1.2178e+00],
#          [ 8.8353e+00,  1.6412e+01,  1.9334e+01,  ..., -1.3634e+00,
#            1.9371e-01, -8.7571e-01],
#          [-1.1459e-02,  9.2475e+00,  1.2803e+01,  ..., -5.9524e+00,
#           -3.8543e+00, -4.1037e+00]],
#
#         [[ 8.5442e+00,  1.1372e+01,  1.2152e+01,  ..., -1.4198e+00,
#           -2.2452e+00, -8.4734e+00],
#          [ 7.6773e+00,  1.6894e+01,  1.8981e+01,  ..., -3.9742e+00,
#           -4.4136e+00, -6.7885e+00],
#          [-3.1808e-02,  1.5253e+01,  1.6907e+01,  ..., -4.2063e+00,
#           -8.5795e+00, -1.1660e+01],
#          ...,
#          [-6.8050e+00,  4.2031e+00,  5.8883e+00,  ..., -6.0571e+00,
#           -5.7968e+00, -1.0420e+01],
#          [-6.3876e+00,  4.8998e+00,  7.3278e+00,  ...,  3.7469e+00,
#            3.5412e+00, -1.0107e+01],
#          [ 2.8885e+00,  5.0220e+00,  5.8498e+00,  ..., -6.4575e+00,
#           -3.7653e+00, -1.1493e+01]],
#
#         ...,
#
#         [[ 1.4805e+01,  1.5689e+01,  1.5385e+01,  ..., -9.3708e+00,
#           -3.5412e+00, -5.2768e+00],
#          [ 1.7033e+01,  1.3856e+01,  8.6113e+00,  ...,  3.6849e-01,
#           -4.6029e-01, -5.1150e+00],
#          [ 1.8900e+01,  1.7527e+01,  1.6166e+01,  ..., -5.3081e+00,
#           -2.5966e+00, -5.0077e+00],
#          ...,
#          [ 2.1441e+01,  1.8439e+01,  1.4625e+01,  ..., -9.9449e+00,
#           -8.4424e+00, -8.5471e+00],
#          [ 2.3515e+01,  2.0586e+01,  1.5571e+01,  ..., -1.0269e+01,
#           -1.2287e+01, -1.0331e+01],
#          [ 1.8922e+01,  1.7794e+01,  1.6082e+01,  ..., -8.6812e+00,
#           -7.3612e+00, -8.9989e+00]],
#
#         [[ 1.6875e+01,  1.8890e+01,  1.8533e+01,  ..., -8.1543e+00,
#           -9.5064e+00, -8.6628e+00],
#          [ 2.2511e+01,  2.1955e+01,  1.9700e+01,  ..., -1.2577e+01,
#           -1.4259e+01, -1.2728e+01],
#          [ 1.8965e+01,  1.8949e+01,  1.7928e+01,  ..., -1.3620e+01,
#           -1.5674e+01, -1.2864e+01],
#          ...,
#          [ 1.6691e+01,  1.8285e+01,  1.6279e+01,  ..., -1.7601e+01,
#           -1.3595e+01, -9.7013e+00],
#          [ 1.7409e+01,  1.8103e+01,  1.5471e+01,  ..., -4.0362e-01,
#            6.2348e-02, -1.8228e+00],
#          [ 8.6134e+00,  1.1645e+01,  1.2296e+01,  ..., -1.0946e+01,
#           -6.8415e+00, -5.1918e+00]],
#
#         [[ 1.5638e+01,  1.5569e+01,  1.3864e+01,  ..., -1.1920e+01,
#           -5.2877e+00, -9.2128e+00],
#          [ 1.6393e+01,  1.8364e+01,  1.6532e+01,  ..., -1.3907e+01,
#           -9.1121e+00, -3.2703e+00],
#          [ 1.8227e+01,  1.8508e+01,  1.5812e+01,  ..., -1.2085e+01,
#           -7.2602e+00, -5.4926e+00],
#          ...,
#          [ 1.6355e+01,  1.1972e+01,  5.3219e+00,  ..., -1.9597e+01,
#           -1.7680e+01, -1.0343e+01],
#          [ 1.6740e+01,  1.3888e+01,  8.2495e+00,  ..., -1.7756e+01,
#           -1.3590e+01, -1.0954e+01],
#          [ 1.4758e+01,  1.3249e+01,  1.2002e+01,  ..., -2.1138e+01,
#           -1.6556e+01, -1.3128e+01]]])

# %%
print(labels.shape)
print(labels)
# Out:
# torch.Size([2988])
# tensor([0., 0., 0.,  ..., 9., 9., 9.])

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(features, labels)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
X_train = X_train.numpy()
X_val = X_val.numpy()
X_test = X_test.numpy()
# Out:
# torch.Size([2390, 501, 40])
# torch.Size([299, 501, 40])
# torch.Size([299, 501, 40])

# %%
X_train, X_val, X_test = normalize_data([X_train, X_val, X_test])

# %%
print_stats(X_train)
# Out:
# Shape: (2390, 501, 40)
# Dtype: float32
#  - Max:      3.490
#  - Min:     -6.966
#  - Mean:     0.000
#  - Std Dev:  1.000
#
# [[[ 0.4324319   0.5235686   0.539371   ...  0.7696717   0.70545137
#     0.38661122]
#   [ 0.7033844   0.6646656   0.48968515 ...  0.4557373   0.37470293
#     0.28158787]
#   [ 0.6878732   0.5070853   0.17866641 ...  0.11812218  0.21876432
#     0.33382416]
#   ...
#   [ 0.96281433  0.99042165  0.913043   ...  0.3897332   0.30100504
#     0.04069782]
#   [ 0.81184167  0.8570251   0.7527065  ...  0.18112832  0.20391558
#    -0.01947931]
#   [ 0.47459522  0.54485965  0.494685   ... -0.20567213 -0.43880492
#    -0.44469675]]
#
#  [[ 0.4593697   0.46746537  0.36676162 ...  2.0687144   1.9302484
#     1.8145031 ]
#   [ 0.29386458  0.42053083  0.43999678 ...  1.4999044   1.5503665
#     1.7049212 ]
#   [ 0.16162515  0.50463533  0.5550691  ...  1.4331344   1.5867832
#     1.5067407 ]
#   ...
#   [ 0.9495273   0.88628864  0.709363   ...  1.095192    0.98355347
#     0.8689831 ]
#   [ 1.0198374   0.91800696  0.7499961  ...  1.2847407   1.1411909
#     0.8641743 ]
#   [-0.44148386 -0.058525    0.30455908 ...  1.4666303   1.1624373
#     1.0241289 ]]
#
#  [[ 0.24783146  0.5006508   0.6302435  ...  1.212564    1.2627566
#     1.2127783 ]
#   [ 1.4131397   1.2349831   0.92942244 ...  0.47275525  0.7287214
#     0.92275715]
#   [ 1.5321876   1.3214856   0.9937352  ...  0.64217114  0.42121303
#     1.0318344 ]
#   ...
#   [-0.25496855  0.8342255   1.3090836  ...  1.522721    1.5491858
#     1.6350312 ]
#   [ 0.4335256   1.1350186   1.4209373  ...  1.6886102   1.2245216
#     1.286778  ]
#   [ 0.62642     0.78556246  0.91535425 ...  1.6975468   1.3001058
#     1.493399  ]]
#
#  ...
#
#  [[ 0.14414711  0.08190597  0.0202277  ...  0.19263129  0.34725058
#     0.6656876 ]
#   [ 0.00363496 -0.15833096 -0.49582973 ... -0.0927386   0.047321
#     0.16425633]
#   [-0.06471685 -0.3158174  -0.578287   ... -0.45919958 -0.36180875
#     0.05281258]
#   ...
#   [-1.3248454  -1.3572724  -1.1765611  ... -0.614744   -1.0435419
#    -0.7347244 ]
#   [-1.175485   -1.2223141  -1.1152496  ... -0.33998555 -0.82400614
#    -0.20956714]
#   [-1.2549996  -1.2360935  -1.2203577  ... -1.3105929  -1.4552653
#    -1.3050566 ]]
#
#  [[-0.16519047 -0.24322219 -0.31168643 ... -1.2341259  -1.2244256
#    -1.2313728 ]
#   [ 0.28479692  0.138109   -0.00683899 ... -2.4386241  -2.4308891
#    -2.4628382 ]
#   [ 0.15039818  0.00616419 -0.18887539 ... -2.1743345  -2.120149
#    -2.1583292 ]
#   ...
#   [ 0.43756756  0.36305517  0.16649282 ... -1.8682808  -1.7066531
#    -1.7493147 ]
#   [ 0.3778361   0.16039516 -0.07675667 ... -1.7429214  -1.7344838
#    -1.7359691 ]
#   [ 0.26584798  0.06002112 -0.165723   ... -2.214719   -2.0762544
#    -2.3655212 ]]
#
#  [[-1.5608464  -1.2430431  -1.0540725  ...  0.5233728   0.4307403
#    -0.47876966]
#   [-2.3438518  -1.0451723  -0.70323765 ...  0.5401831   0.38367882
#    -0.5151845 ]
#   [-1.665044   -0.9599201  -0.7006867  ...  0.8268368   0.65159917
#    -0.16578297]
#   ...
#   [-1.5730156  -1.2396734  -0.7350856  ...  0.72168964  0.80240923
#     0.47711882]
#   [-0.8293664  -0.2443433   0.52830046 ...  0.7999428   0.7420067
#     0.60511255]
#   [-1.1772511  -0.6543724  -0.3298858  ...  0.69403875  0.4145011
#     0.1218923 ]]]

# %%
print_stats(X_test)
# Out:
# Shape: (299, 501, 40)
# Dtype: float32
#  - Max:      3.273
#  - Min:     -6.894
#  - Mean:    -0.000
#  - Std Dev:  1.000
#
# [[[-7.21423090e-01 -5.22287428e-01 -3.60289365e-01 ... -5.01120329e-01
#    -6.41531169e-01 -5.87834418e-01]
#   [-1.75856143e-01 -2.10751966e-01 -1.72389939e-01 ... -1.02217495e+00
#    -1.16527343e+00 -1.31108689e+00]
#   [-2.88261831e-01 -2.52403975e-01 -3.84938084e-02 ... -1.15346074e+00
#    -1.37879086e+00 -1.40814006e+00]
#   ...
#   [ 9.33891654e-01  7.08390117e-01  4.79303271e-01 ...  7.02170849e-01
#     6.73808157e-01  6.89280033e-01]
#   [ 9.28216517e-01  7.55937576e-01  5.31520665e-01 ...  1.05713136e-01
#     1.21589631e-01  2.33861119e-01]
#   [ 8.27440143e-01  8.96312952e-01  9.26336646e-01 ... -7.18217641e-02
#    -2.13481989e-02 -2.00158879e-02]]
#
#  [[ 3.50939184e-01  3.99787575e-01  5.60280561e-01 ...  2.36264989e-02
#     7.07784817e-02  1.01495169e-01]
#   [ 2.95927107e-01  1.10305712e-01  3.61811966e-01 ...  1.67332247e-01
#     2.37747326e-01  4.27217603e-01]
#   [ 4.44775164e-01  1.31313428e-02  4.27855439e-02 ...  2.17893675e-01
#     2.15388879e-01  1.47922365e-02]
#   ...
#   [-1.63369334e+00 -2.00877523e+00 -1.84605086e+00 ... -2.31717587e-01
#    -5.34950316e-01 -1.39343038e-01]
#   [-1.82679558e+00 -1.69755065e+00 -1.46431184e+00 ... -3.71856123e-01
#    -4.63633239e-01  7.45932683e-02]
#   [-1.26817417e+00 -1.62925231e+00 -1.85401940e+00 ... -2.32636377e-01
#    -1.90879866e-01  1.27007365e-01]]
#
#  [[ 1.65378356e+00  1.49567449e+00  1.27383626e+00 ...  2.66061008e-01
#     4.82303888e-01  7.07821310e-01]
#   [ 1.40434670e+00  1.12488031e+00  6.99851155e-01 ... -2.87545145e-01
#     4.56444532e-01  8.72992337e-01]
#   [ 1.34401131e+00  1.08192360e+00  7.32314527e-01 ...  1.61350429e+00
#     1.69101810e+00  1.71277547e+00]
#   ...
#   [-3.73235130e+00 -2.86963677e+00 -2.12682199e+00 ...  1.11531746e+00
#     1.16440856e+00  1.04529333e+00]
#   [-2.50068140e+00 -2.32636070e+00 -1.27686858e+00 ...  1.04449725e+00
#     1.13844645e+00  9.82670963e-01]
#   [ 2.62551397e-01  3.84118795e-01  5.58106780e-01 ...  9.58284199e-01
#     1.01579869e+00  9.92435515e-01]]
#
#  ...
#
#  [[-4.15114641e-01 -5.30084550e-01 -5.00123918e-01 ...  1.81637600e-01
#    -1.65435120e-01 -1.39489723e-02]
#   [-1.48622894e+00 -1.81253040e+00 -1.96020949e+00 ...  7.43556380e-01
#     8.95542681e-01  9.89683270e-01]
#   [-1.19943464e+00 -1.42315698e+00 -1.50827706e+00 ...  1.09181499e+00
#     9.93681014e-01  7.24700511e-01]
#   ...
#   [ 4.04429525e-01  5.41605711e-01  4.37442005e-01 ... -2.62940419e-03
#     1.29311636e-01  1.43645126e-02]
#   [ 1.17418063e+00  1.07831931e+00  8.48604679e-01 ...  1.87909797e-01
#     1.68335289e-01 -3.60529646e-02]
#   [ 1.08449543e+00  1.22135210e+00  1.17780304e+00 ...  7.03706324e-01
#     7.10551023e-01  7.11178839e-01]]
#
#  [[-1.11178167e-01 -9.02516544e-02 -1.52015999e-01 ... -7.73556828e-01
#    -6.47197306e-01 -5.57093859e-01]
#   [-4.41932768e-01 -4.72682774e-01 -7.23034382e-01 ... -7.94014990e-01
#    -6.16624117e-01 -8.55822802e-01]
#   [-1.42037964e+00 -1.79994714e+00 -1.65608716e+00 ... -1.22357619e+00
#    -9.03835177e-01 -1.09018624e+00]
#   ...
#   [ 6.97340310e-01  7.56271124e-01  6.42686963e-01 ... -6.76693082e-01
#    -7.14260876e-01 -1.16007340e+00]
#   [ 6.74021900e-01  7.10348904e-01  5.59642792e-01 ... -5.13344646e-01
#    -3.95452619e-01 -7.26300538e-01]
#   [ 7.49143422e-01  6.22728944e-01  3.97164017e-01 ... -9.12042201e-01
#    -9.63425934e-01 -1.35714030e+00]]
#
#  [[-5.24182677e-01 -5.54230690e-01 -4.16662574e-01 ...  4.61052060e-01
#     7.37283766e-01  5.69854379e-01]
#   [-1.13256788e+00 -9.56571221e-01 -6.99909568e-01 ...  1.93539813e-01
#     2.70587295e-01  1.93505198e-01]
#   [-1.15918541e+00 -1.40250742e+00 -1.80501366e+00 ...  5.96993446e-01
#     7.47165203e-01  5.29556990e-01]
#   ...
#   [-1.96069971e-01 -1.93750843e-01 -3.73135865e-01 ...  2.34962180e-01
#     2.30295107e-01  2.89654255e-01]
#   [-5.53702116e-01 -5.65994024e-01 -3.95785421e-01 ... -8.42880923e-03
#    -8.58976617e-02 -8.33596289e-02]
#   [-4.70570952e-01 -8.54680419e-01 -1.32880068e+00 ... -2.77476251e-01
#    -3.01972717e-01 -3.62405151e-01]]]

# %%
save_numpy_arrays([X_train, y_train, X_val, y_val, X_test, y_test], 
                  ['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy', 'data_test_X.npy', 'data_test_y.npy'],
                 path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy', 'data_test_X.npy', 'data_test_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')
