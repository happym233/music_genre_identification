# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %%
#os.chdir('..')
#os.listdir()

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicLSTM import MusicLSTM
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([2390, 501, 40])
# torch.Size([2390])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[ 0.4324,  0.5236,  0.5394,  ...,  0.7697,  0.7055,  0.3866],
#         [ 0.7034,  0.6647,  0.4897,  ...,  0.4557,  0.3747,  0.2816],
#         [ 0.6879,  0.5071,  0.1787,  ...,  0.1181,  0.2188,  0.3338],
#         ...,
#         [ 0.9628,  0.9904,  0.9130,  ...,  0.3897,  0.3010,  0.0407],
#         [ 0.8118,  0.8570,  0.7527,  ...,  0.1811,  0.2039, -0.0195],
#         [ 0.4746,  0.5449,  0.4947,  ..., -0.2057, -0.4388, -0.4447]])
# tensor(0)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([299, 501, 40])
# torch.Size([299])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicLSTM(input_size=40,
        hidden_size=40,
        output_size=10,
        num_layers=5,
        dropout=0.15,
        bidirectional=True
    )

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
#X_train = X_train[:, range(0, n_time + 1, 4), :]
#X_val = X_val[:, range(0, n_time + 1, 4), :]

# %%
X_a = X_train[:10]
pred = model(X_a)

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 50
num_epoch = 100
model_name = 'LSTM_bidirectional'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train, y_train, X_val, y_val), loss, optimizer, batch_size=batch_size, num_epoch=num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 1.9775
# training accuracy: 23.97% validation accuracy: 22.41%
# Epoch  1: loss on final training batch: 1.7622
# training accuracy: 34.10% validation accuracy: 31.44%
# Epoch  2: loss on final training batch: 1.7158
# training accuracy: 30.59% validation accuracy: 25.42%
# Epoch  3: loss on final training batch: 1.7015
# training accuracy: 40.96% validation accuracy: 39.13%
# Epoch  4: loss on final training batch: 1.5581
# training accuracy: 46.53% validation accuracy: 43.48%
# Epoch  5: loss on final training batch: 1.5206
# training accuracy: 49.29% validation accuracy: 47.83%
# Epoch  6: loss on final training batch: 1.2906
# training accuracy: 53.14% validation accuracy: 50.17%
# Epoch  7: loss on final training batch: 1.2578
# training accuracy: 58.33% validation accuracy: 55.85%
# Epoch  8: loss on final training batch: 1.2264
# training accuracy: 58.83% validation accuracy: 55.85%
# Epoch  9: loss on final training batch: 1.1812
# training accuracy: 60.46% validation accuracy: 58.19%
# Epoch 10: loss on final training batch: 1.3739
# training accuracy: 54.69% validation accuracy: 53.18%
# Epoch 11: loss on final training batch: 1.1288
# training accuracy: 59.96% validation accuracy: 55.18%
# Epoch 12: loss on final training batch: 1.0022
# training accuracy: 65.56% validation accuracy: 61.20%
# Epoch 13: loss on final training batch: 1.0387
# training accuracy: 63.39% validation accuracy: 57.86%
# Epoch 14: loss on final training batch: 0.8847
# training accuracy: 69.12% validation accuracy: 63.21%
# Epoch 15: loss on final training batch: 0.9721
# training accuracy: 69.46% validation accuracy: 63.55%
# Epoch 16: loss on final training batch: 0.9054
# training accuracy: 70.21% validation accuracy: 61.20%
# Epoch 17: loss on final training batch: 0.9675
# training accuracy: 69.25% validation accuracy: 64.55%
# Epoch 18: loss on final training batch: 0.8308
# training accuracy: 73.14% validation accuracy: 64.21%
# Epoch 19: loss on final training batch: 0.6747
# training accuracy: 75.73% validation accuracy: 71.24%
# Epoch 20: loss on final training batch: 0.8172
# training accuracy: 72.93% validation accuracy: 66.22%
# Epoch 21: loss on final training batch: 0.7092
# training accuracy: 75.15% validation accuracy: 68.90%
# Epoch 22: loss on final training batch: 0.6557
# training accuracy: 75.44% validation accuracy: 68.23%
# Epoch 23: loss on final training batch: 0.5842
# training accuracy: 73.01% validation accuracy: 65.22%
# Epoch 24: loss on final training batch: 0.6529
# training accuracy: 79.25% validation accuracy: 71.91%
# Epoch 25: loss on final training batch: 0.6065
# training accuracy: 77.28% validation accuracy: 67.89%
# Epoch 26: loss on final training batch: 0.7840
# training accuracy: 78.49% validation accuracy: 68.56%
# Epoch 27: loss on final training batch: 0.4886
# training accuracy: 80.84% validation accuracy: 70.23%
# Epoch 28: loss on final training batch: 0.6431
# training accuracy: 76.61% validation accuracy: 65.22%
# Epoch 29: loss on final training batch: 0.4838
# training accuracy: 79.50% validation accuracy: 67.56%
# Epoch 30: loss on final training batch: 0.4748
# training accuracy: 83.05% validation accuracy: 70.90%
# Epoch 31: loss on final training batch: 0.5558
# training accuracy: 83.18% validation accuracy: 67.89%
# Epoch 32: loss on final training batch: 0.6451
# training accuracy: 77.99% validation accuracy: 67.89%
# Epoch 33: loss on final training batch: 0.4052
# training accuracy: 84.48% validation accuracy: 71.57%
# Epoch 34: loss on final training batch: 0.4379
# training accuracy: 82.89% validation accuracy: 71.57%
# Epoch 35: loss on final training batch: 0.4123
# training accuracy: 84.18% validation accuracy: 69.23%
# Epoch 36: loss on final training batch: 0.3110
# training accuracy: 87.41% validation accuracy: 74.25%
# Epoch 37: loss on final training batch: 0.9214
# training accuracy: 72.05% validation accuracy: 66.22%
# Epoch 38: loss on final training batch: 0.6530
# training accuracy: 78.45% validation accuracy: 68.56%
# Epoch 39: loss on final training batch: 0.7340
# training accuracy: 80.54% validation accuracy: 71.91%
# Epoch 40: loss on final training batch: 0.5888
# training accuracy: 79.37% validation accuracy: 72.24%
# Epoch 41: loss on final training batch: 0.4803
# training accuracy: 85.15% validation accuracy: 70.90%
# Epoch 42: loss on final training batch: 0.4066
# training accuracy: 85.19% validation accuracy: 71.57%
# Epoch 43: loss on final training batch: 0.7222
# training accuracy: 78.12% validation accuracy: 65.55%
# Epoch 44: loss on final training batch: 0.4183
# training accuracy: 86.61% validation accuracy: 76.92%
# Epoch 45: loss on final training batch: 0.4091
# training accuracy: 85.56% validation accuracy: 73.91%
# Epoch 46: loss on final training batch: 0.4349
# training accuracy: 90.00% validation accuracy: 73.58%
# Epoch 47: loss on final training batch: 0.3417
# training accuracy: 88.24% validation accuracy: 74.58%
# Epoch 48: loss on final training batch: 0.3693
# training accuracy: 82.64% validation accuracy: 69.90%
# Epoch 49: loss on final training batch: 0.5055
# training accuracy: 82.97% validation accuracy: 68.56%
# Epoch 50: loss on final training batch: 0.3534
# training accuracy: 88.54% validation accuracy: 72.58%
# Epoch 51: loss on final training batch: 0.3224
# training accuracy: 89.08% validation accuracy: 75.25%
# Epoch 52: loss on final training batch: 0.3315
# training accuracy: 86.86% validation accuracy: 73.91%
# Epoch 53: loss on final training batch: 0.3690
# training accuracy: 82.26% validation accuracy: 71.57%
# Epoch 54: loss on final training batch: 0.3341
# training accuracy: 89.87% validation accuracy: 75.59%
# Epoch 55: loss on final training batch: 0.3724
# training accuracy: 88.62% validation accuracy: 77.59%
# Epoch 56: loss on final training batch: 0.4626
# training accuracy: 87.66% validation accuracy: 72.91%
# Epoch 57: loss on final training batch: 0.2838
# training accuracy: 88.74% validation accuracy: 73.58%
# Epoch 58: loss on final training batch: 0.4455
# training accuracy: 84.90% validation accuracy: 71.24%
# Epoch 59: loss on final training batch: 0.2366
# training accuracy: 92.05% validation accuracy: 75.92%
# Epoch 60: loss on final training batch: 0.2762
# training accuracy: 92.22% validation accuracy: 73.24%
# Epoch 61: loss on final training batch: 0.3547
# training accuracy: 90.46% validation accuracy: 76.25%
# Epoch 62: loss on final training batch: 0.2663
# training accuracy: 91.21% validation accuracy: 76.25%
# Epoch 63: loss on final training batch: 0.5363
# training accuracy: 84.48% validation accuracy: 72.91%
# Epoch 64: loss on final training batch: 0.3330
# training accuracy: 90.21% validation accuracy: 76.92%
# Epoch 65: loss on final training batch: 0.2459
# training accuracy: 92.43% validation accuracy: 78.60%
# Epoch 66: loss on final training batch: 0.2913
# training accuracy: 91.17% validation accuracy: 75.59%
# Epoch 67: loss on final training batch: 0.2604
# training accuracy: 94.35% validation accuracy: 77.59%
# Epoch 68: loss on final training batch: 0.2981
# training accuracy: 92.89% validation accuracy: 75.92%
# Epoch 69: loss on final training batch: 0.3924
# training accuracy: 88.79% validation accuracy: 72.91%
# Epoch 70: loss on final training batch: 1.3896
# training accuracy: 72.89% validation accuracy: 66.89%
# Epoch 71: loss on final training batch: 0.6595
# training accuracy: 85.10% validation accuracy: 71.91%
# Epoch 72: loss on final training batch: 0.5159
# training accuracy: 89.21% validation accuracy: 70.57%
# Epoch 73: loss on final training batch: 0.4777
# training accuracy: 89.75% validation accuracy: 75.92%
# Epoch 74: loss on final training batch: 0.3818
# training accuracy: 91.42% validation accuracy: 74.25%
# Epoch 75: loss on final training batch: 0.3219
# training accuracy: 92.43% validation accuracy: 75.25%
# Epoch 76: loss on final training batch: 0.2465
# training accuracy: 92.38% validation accuracy: 71.91%
# Epoch 77: loss on final training batch: 0.2410
# training accuracy: 92.68% validation accuracy: 75.92%
# Epoch 78: loss on final training batch: 0.2098
# training accuracy: 90.54% validation accuracy: 76.92%
# Epoch 79: loss on final training batch: 0.1612
# training accuracy: 94.44% validation accuracy: 76.92%
# Epoch 80: loss on final training batch: 0.3361
# training accuracy: 90.75% validation accuracy: 73.24%
# Epoch 81: loss on final training batch: 0.2470
# training accuracy: 92.68% validation accuracy: 75.25%
# Epoch 82: loss on final training batch: 0.1939
# training accuracy: 94.69% validation accuracy: 77.59%
# Epoch 83: loss on final training batch: 0.1632
# training accuracy: 93.89% validation accuracy: 74.92%
# Epoch 84: loss on final training batch: 0.2644
# training accuracy: 94.02% validation accuracy: 75.92%
# Epoch 85: loss on final training batch: 0.5972
# training accuracy: 88.54% validation accuracy: 73.58%
# Epoch 86: loss on final training batch: 0.1947
# training accuracy: 95.52% validation accuracy: 77.59%
# Epoch 87: loss on final training batch: 0.1767
# training accuracy: 94.94% validation accuracy: 77.59%
# Epoch 88: loss on final training batch: 0.2588
# training accuracy: 93.43% validation accuracy: 76.25%
# Epoch 89: loss on final training batch: 0.3627
# training accuracy: 87.99% validation accuracy: 69.23%
# Epoch 90: loss on final training batch: 0.3129
# training accuracy: 89.54% validation accuracy: 76.92%
# Epoch 91: loss on final training batch: 0.1857
# training accuracy: 91.72% validation accuracy: 73.91%
# Epoch 92: loss on final training batch: 0.2138
# training accuracy: 94.64% validation accuracy: 73.58%
# Epoch 93: loss on final training batch: 0.1624
# training accuracy: 95.44% validation accuracy: 76.92%
# Epoch 94: loss on final training batch: 0.1112
# training accuracy: 94.48% validation accuracy: 78.26%
# Epoch 95: loss on final training batch: 0.0542
# training accuracy: 96.95% validation accuracy: 75.92%
# Epoch 96: loss on final training batch: 0.0859
# training accuracy: 95.27% validation accuracy: 74.58%
# Epoch 97: loss on final training batch: 0.0583
# training accuracy: 97.32% validation accuracy: 75.59%
# Epoch 98: loss on final training batch: 0.4057
# training accuracy: 87.49% validation accuracy: 74.25%
# Epoch 99: loss on final training batch: 0.2655
# training accuracy: 91.38% validation accuracy: 74.25%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
