# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  'data_loader',
#  'data_processor',
#  'jupyter',
#  'loggers',
#  'main.py',
#  'models',
#  'original_data',
#  'processed_data',
#  'README.md',
#  'saved_models',
#  'trainers']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.Linear import LogisticRegression
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
data_train, data_val = load_numpy_arrays(['data_train.npy', 'data_val.npy'], 
                                            path_prefix='processed_data/processed_features/4-genres/')

# %%
X_train, y_train = data_train[:, :-1], data_train[:, -1]
X_val, y_val = data_val[:, :-1], data_val[:, -1]

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([3194, 57])
# torch.Size([3194])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([-1.5641, -0.8388, -0.6725, -0.4727, -1.1367, -0.9590, -1.2418, -0.6418,
#         -1.4292, -1.0178, -0.6124, -0.7128, -0.3501, -0.5114, -0.2725, -0.8137,
#          1.1590, -0.5819, -0.5639,  1.6685, -0.7834, -0.0464, -0.2956, -2.5771,
#         -0.9344, -0.9167, -0.8403, -2.0586, -0.8075, -0.1764, -1.0677, -0.9795,
#         -0.4747,  2.1352, -1.0326,  0.9913, -0.8415,  0.7881, -0.2459, -0.6958,
#          0.1568,  0.6649, -0.4841, -1.1753,  0.7005, -0.8920, -0.3307, -0.8273,
#         -0.4440,  0.2094, -0.4068, -0.3852,  0.1505, -0.7181,  0.3104, -1.0743,
#          1.3346])
# tensor(1)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([400, 57])
# torch.Size([400])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
#define model here
# for example
class MLP(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_dim, 100),
            nn.ReLU(),
            nn.Linear(100, output_dim)
        )
        
    def forward(self, x):
        x = self.layers(x)
        return x

# %%
# define a model instance
# eg. MLP

model = MLP(57, 4)

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.01
batch_size = 100
num_epoch = 20
model_name = 'MLP'
saved_model_name = 'saved_models/saved_' + model_name + '_csv.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train, y_train, X_val, y_val), 
                                                                                                                            loss, optimizer, batch_size=batch_size, num_epoch=num_epoch)
# Out:
# Epoch  0: loss on final training batch: 0.4371
# training accuracy: 89.23% validation accuracy: 90.25%
# Epoch  1: loss on final training batch: 0.2134
# training accuracy: 94.24% validation accuracy: 92.25%
# Epoch  2: loss on final training batch: 0.1225
# training accuracy: 96.06% validation accuracy: 92.50%
# Epoch  3: loss on final training batch: 0.0825
# training accuracy: 97.81% validation accuracy: 93.25%
# Epoch  4: loss on final training batch: 0.0668
# training accuracy: 98.50% validation accuracy: 93.75%
# Epoch  5: loss on final training batch: 0.0476
# training accuracy: 98.90% validation accuracy: 95.00%
# Epoch  6: loss on final training batch: 0.0511
# training accuracy: 98.50% validation accuracy: 94.25%
# Epoch  7: loss on final training batch: 0.0403
# training accuracy: 98.06% validation accuracy: 93.25%
# Epoch  8: loss on final training batch: 0.0203
# training accuracy: 99.53% validation accuracy: 94.75%
# Epoch  9: loss on final training batch: 0.0290
# training accuracy: 98.78% validation accuracy: 94.00%
# Epoch 10: loss on final training batch: 0.0403
# training accuracy: 98.50% validation accuracy: 94.00%
# Epoch 11: loss on final training batch: 0.0246
# training accuracy: 98.37% validation accuracy: 93.50%
# Epoch 12: loss on final training batch: 0.0103
# training accuracy: 99.59% validation accuracy: 95.00%
# Epoch 13: loss on final training batch: 0.0085
# training accuracy: 99.75% validation accuracy: 95.75%
# Epoch 14: loss on final training batch: 0.0079
# training accuracy: 99.87% validation accuracy: 96.00%
# Epoch 15: loss on final training batch: 0.0083
# training accuracy: 99.87% validation accuracy: 95.75%
# Epoch 16: loss on final training batch: 0.0105
# training accuracy: 99.87% validation accuracy: 95.50%
# Epoch 17: loss on final training batch: 0.0036
# training accuracy: 99.91% validation accuracy: 95.00%
# Epoch 18: loss on final training batch: 0.0025
# training accuracy: 99.91% validation accuracy: 95.75%
# Epoch 19: loss on final training batch: 0.0045
# training accuracy: 99.97% validation accuracy: 95.50%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)

# %% [markdown]
# ## Save model
#
# Save model in 'saved_models/saved_modelname_csv.pt'

# %%
torch.save(model.state_dict(), saved_model_name)
