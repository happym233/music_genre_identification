# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['opt',
#  'dev',
#  'run',
#  'etc',
#  'root',
#  'usr',
#  'boot',
#  'srv',
#  'sys',
#  'proc',
#  'var',
#  'home',
#  'tmp',
#  'lib64',
#  'mnt',
#  'media',
#  'lib',
#  'sbin',
#  'bin',
#  '.dockerenv',
#  'tools',
#  'datalab',
#  'tensorflow-1.15.2',
#  'content',
#  'python-apt',
#  'lib32']

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicLSTM import MusicLSTM
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([2390, 501, 40])
# torch.Size([2390])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[ 0.4324,  0.5236,  0.5394,  ...,  0.7697,  0.7055,  0.3866],
#         [ 0.7034,  0.6647,  0.4897,  ...,  0.4557,  0.3747,  0.2816],
#         [ 0.6879,  0.5071,  0.1787,  ...,  0.1181,  0.2188,  0.3338],
#         ...,
#         [ 0.9628,  0.9904,  0.9130,  ...,  0.3897,  0.3010,  0.0407],
#         [ 0.8118,  0.8570,  0.7527,  ...,  0.1811,  0.2039, -0.0195],
#         [ 0.4746,  0.5449,  0.4947,  ..., -0.2057, -0.4388, -0.4447]])
# tensor(0)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([299, 501, 40])
# torch.Size([299])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicLSTM(input_size=40,
        hidden_size=80,
        output_size=10,
        num_layers=5,
        dropout=0.15
    )

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
#X_train = X_train[:, range(0, n_time + 1, 4), :]
#X_val = X_val[:, range(0, n_time + 1, 4), :]

# %%
X_a = X_train[:10]
pred = model(X_a)

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 200
num_epoch = 200
model_name = 'LSTM'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train, y_train, X_val, y_val), loss, optimizer, batch_size=batch_size, num_epoch=num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 2.2458
# training accuracy: 14.27% validation accuracy: 9.70%
# Epoch  1: loss on final training batch: 2.0528
# training accuracy: 19.50% validation accuracy: 19.73%
# Epoch  2: loss on final training batch: 2.0223
# training accuracy: 21.46% validation accuracy: 17.39%
# Epoch  3: loss on final training batch: 1.9850
# training accuracy: 23.43% validation accuracy: 25.75%
# Epoch  4: loss on final training batch: 1.9364
# training accuracy: 24.27% validation accuracy: 25.08%
# Epoch  5: loss on final training batch: 1.8800
# training accuracy: 27.28% validation accuracy: 29.43%
# Epoch  6: loss on final training batch: 1.8213
# training accuracy: 29.33% validation accuracy: 32.78%
# Epoch  7: loss on final training batch: 1.7369
# training accuracy: 32.13% validation accuracy: 35.79%
# Epoch  8: loss on final training batch: 1.6857
# training accuracy: 34.81% validation accuracy: 37.79%
# Epoch  9: loss on final training batch: 1.6778
# training accuracy: 35.73% validation accuracy: 36.45%
# Epoch 10: loss on final training batch: 1.6647
# training accuracy: 38.03% validation accuracy: 39.80%
# Epoch 11: loss on final training batch: 1.6112
# training accuracy: 39.75% validation accuracy: 41.47%
# Epoch 12: loss on final training batch: 1.6689
# training accuracy: 39.41% validation accuracy: 41.81%
# Epoch 13: loss on final training batch: 1.6159
# training accuracy: 41.46% validation accuracy: 43.81%
# Epoch 14: loss on final training batch: 1.5420
# training accuracy: 44.60% validation accuracy: 43.14%
# Epoch 15: loss on final training batch: 1.5035
# training accuracy: 47.95% validation accuracy: 48.16%
# Epoch 16: loss on final training batch: 1.5359
# training accuracy: 45.73% validation accuracy: 42.14%
# Epoch 17: loss on final training batch: 1.4605
# training accuracy: 48.12% validation accuracy: 45.82%
# Epoch 18: loss on final training batch: 1.3851
# training accuracy: 51.34% validation accuracy: 47.83%
# Epoch 19: loss on final training batch: 1.3432
# training accuracy: 52.97% validation accuracy: 51.51%
# Epoch 20: loss on final training batch: 1.2894
# training accuracy: 54.44% validation accuracy: 50.84%
# Epoch 21: loss on final training batch: 1.2693
# training accuracy: 55.69% validation accuracy: 52.17%
# Epoch 22: loss on final training batch: 1.2292
# training accuracy: 55.90% validation accuracy: 54.52%
# Epoch 23: loss on final training batch: 1.2213
# training accuracy: 56.74% validation accuracy: 54.18%
# Epoch 24: loss on final training batch: 1.2126
# training accuracy: 58.91% validation accuracy: 52.84%
# Epoch 25: loss on final training batch: 1.1595
# training accuracy: 59.46% validation accuracy: 58.53%
# Epoch 26: loss on final training batch: 1.1610
# training accuracy: 61.55% validation accuracy: 59.53%
# Epoch 27: loss on final training batch: 1.1681
# training accuracy: 61.55% validation accuracy: 59.53%
# Epoch 28: loss on final training batch: 1.1185
# training accuracy: 61.88% validation accuracy: 57.19%
# Epoch 29: loss on final training batch: 1.0690
# training accuracy: 65.19% validation accuracy: 59.87%
# Epoch 30: loss on final training batch: 1.0764
# training accuracy: 64.44% validation accuracy: 58.19%
# Epoch 31: loss on final training batch: 1.0651
# training accuracy: 66.61% validation accuracy: 57.19%
# Epoch 32: loss on final training batch: 1.1310
# training accuracy: 62.30% validation accuracy: 56.52%
# Epoch 33: loss on final training batch: 0.9984
# training accuracy: 67.45% validation accuracy: 60.20%
# Epoch 34: loss on final training batch: 1.0528
# training accuracy: 66.53% validation accuracy: 59.20%
# Epoch 35: loss on final training batch: 0.9864
# training accuracy: 68.58% validation accuracy: 58.86%
# Epoch 36: loss on final training batch: 0.9832
# training accuracy: 67.74% validation accuracy: 59.20%
# Epoch 37: loss on final training batch: 0.9178
# training accuracy: 70.54% validation accuracy: 63.21%
# Epoch 38: loss on final training batch: 0.9163
# training accuracy: 69.41% validation accuracy: 61.87%
# Epoch 39: loss on final training batch: 0.9834
# training accuracy: 68.79% validation accuracy: 60.54%
# Epoch 40: loss on final training batch: 0.9621
# training accuracy: 69.54% validation accuracy: 63.21%
# Epoch 41: loss on final training batch: 0.9278
# training accuracy: 70.42% validation accuracy: 62.88%
# Epoch 42: loss on final training batch: 0.9549
# training accuracy: 68.62% validation accuracy: 61.54%
# Epoch 43: loss on final training batch: 0.9522
# training accuracy: 67.66% validation accuracy: 60.20%
# Epoch 44: loss on final training batch: 1.0943
# training accuracy: 64.73% validation accuracy: 59.53%
# Epoch 45: loss on final training batch: 0.9216
# training accuracy: 68.91% validation accuracy: 62.88%
# Epoch 46: loss on final training batch: 0.8328
# training accuracy: 72.97% validation accuracy: 66.22%
# Epoch 47: loss on final training batch: 0.8059
# training accuracy: 72.34% validation accuracy: 64.55%
# Epoch 48: loss on final training batch: 0.8220
# training accuracy: 75.02% validation accuracy: 66.56%
# Epoch 49: loss on final training batch: 0.7580
# training accuracy: 76.19% validation accuracy: 68.23%
# Epoch 50: loss on final training batch: 0.8372
# training accuracy: 72.76% validation accuracy: 63.88%
# Epoch 51: loss on final training batch: 0.8972
# training accuracy: 71.46% validation accuracy: 65.22%
# Epoch 52: loss on final training batch: 0.8132
# training accuracy: 73.18% validation accuracy: 67.89%
# Epoch 53: loss on final training batch: 0.7582
# training accuracy: 77.20% validation accuracy: 68.90%
# Epoch 54: loss on final training batch: 0.6947
# training accuracy: 77.95% validation accuracy: 71.24%
# Epoch 55: loss on final training batch: 0.6880
# training accuracy: 79.67% validation accuracy: 70.23%
# Epoch 56: loss on final training batch: 0.7077
# training accuracy: 79.16% validation accuracy: 68.56%
# Epoch 57: loss on final training batch: 0.6819
# training accuracy: 78.58% validation accuracy: 66.89%
# Epoch 58: loss on final training batch: 0.6863
# training accuracy: 81.34% validation accuracy: 71.91%
# Epoch 59: loss on final training batch: 0.6858
# training accuracy: 80.13% validation accuracy: 68.90%
# Epoch 60: loss on final training batch: 0.7476
# training accuracy: 77.45% validation accuracy: 67.56%
# Epoch 61: loss on final training batch: 0.7021
# training accuracy: 78.33% validation accuracy: 66.56%
# Epoch 62: loss on final training batch: 0.6351
# training accuracy: 81.72% validation accuracy: 70.90%
# Epoch 63: loss on final training batch: 0.5983
# training accuracy: 82.13% validation accuracy: 70.23%
# Epoch 64: loss on final training batch: 0.6123
# training accuracy: 82.01% validation accuracy: 72.58%
# Epoch 65: loss on final training batch: 0.6508
# training accuracy: 80.50% validation accuracy: 66.56%
# Epoch 66: loss on final training batch: 0.5782
# training accuracy: 83.47% validation accuracy: 72.24%
# Epoch 67: loss on final training batch: 0.6057
# training accuracy: 82.34% validation accuracy: 69.23%
# Epoch 68: loss on final training batch: 0.6050
# training accuracy: 82.26% validation accuracy: 70.57%
# Epoch 69: loss on final training batch: 0.5230
# training accuracy: 85.77% validation accuracy: 73.24%
# Epoch 70: loss on final training batch: 0.5579
# training accuracy: 84.52% validation accuracy: 68.23%
# Epoch 71: loss on final training batch: 0.5455
# training accuracy: 83.60% validation accuracy: 69.90%
# Epoch 72: loss on final training batch: 0.5806
# training accuracy: 80.17% validation accuracy: 64.21%
# Epoch 73: loss on final training batch: 0.5683
# training accuracy: 83.89% validation accuracy: 71.57%
# Epoch 74: loss on final training batch: 0.5804
# training accuracy: 85.06% validation accuracy: 70.23%
# Epoch 75: loss on final training batch: 0.6245
# training accuracy: 82.80% validation accuracy: 65.22%
# Epoch 76: loss on final training batch: 0.7469
# training accuracy: 77.87% validation accuracy: 67.89%
# Epoch 77: loss on final training batch: 0.5329
# training accuracy: 85.65% validation accuracy: 72.58%
# Epoch 78: loss on final training batch: 0.4762
# training accuracy: 84.98% validation accuracy: 69.23%
# Epoch 79: loss on final training batch: 0.4527
# training accuracy: 86.15% validation accuracy: 74.58%
# Epoch 80: loss on final training batch: 0.4845
# training accuracy: 84.39% validation accuracy: 71.57%
# Epoch 81: loss on final training batch: 0.5452
# training accuracy: 82.72% validation accuracy: 71.91%
# Epoch 82: loss on final training batch: 0.4939
# training accuracy: 85.73% validation accuracy: 69.57%
# Epoch 83: loss on final training batch: 0.4781
# training accuracy: 86.11% validation accuracy: 70.90%
# Epoch 84: loss on final training batch: 0.5274
# training accuracy: 84.10% validation accuracy: 70.90%
# Epoch 85: loss on final training batch: 0.5692
# training accuracy: 83.68% validation accuracy: 67.89%
# Epoch 86: loss on final training batch: 0.4953
# training accuracy: 84.94% validation accuracy: 70.23%
# Epoch 87: loss on final training batch: 0.4945
# training accuracy: 85.19% validation accuracy: 70.90%
# Epoch 88: loss on final training batch: 0.4502
# training accuracy: 86.74% validation accuracy: 72.91%
# Epoch 89: loss on final training batch: 0.4822
# training accuracy: 86.69% validation accuracy: 70.23%
# Epoch 90: loss on final training batch: 0.4602
# training accuracy: 86.78% validation accuracy: 73.24%
# Epoch 91: loss on final training batch: 0.4430
# training accuracy: 89.08% validation accuracy: 70.23%
# Epoch 92: loss on final training batch: 0.4467
# training accuracy: 89.33% validation accuracy: 71.24%
# Epoch 93: loss on final training batch: 0.3998
# training accuracy: 88.91% validation accuracy: 73.24%
# Epoch 94: loss on final training batch: 0.4198
# training accuracy: 89.92% validation accuracy: 71.91%
# Epoch 95: loss on final training batch: 0.4235
# training accuracy: 89.33% validation accuracy: 73.91%
# Epoch 96: loss on final training batch: 0.4264
# training accuracy: 89.29% validation accuracy: 69.23%
# Epoch 97: loss on final training batch: 0.4057
# training accuracy: 89.29% validation accuracy: 72.24%
# Epoch 98: loss on final training batch: 0.4192
# training accuracy: 87.62% validation accuracy: 72.91%
# Epoch 99: loss on final training batch: 0.4620
# training accuracy: 88.74% validation accuracy: 72.91%
# Epoch 100: loss on final training batch: 0.5353
# training accuracy: 85.31% validation accuracy: 76.92%
# Epoch 101: loss on final training batch: 0.3954
# training accuracy: 89.83% validation accuracy: 73.58%
# Epoch 102: loss on final training batch: 0.4253
# training accuracy: 90.25% validation accuracy: 71.91%
# Epoch 103: loss on final training batch: 0.3729
# training accuracy: 90.96% validation accuracy: 72.58%
# Epoch 104: loss on final training batch: 0.3140
# training accuracy: 92.13% validation accuracy: 73.58%
# Epoch 105: loss on final training batch: 0.3186
# training accuracy: 91.92% validation accuracy: 70.57%
# Epoch 106: loss on final training batch: 0.3964
# training accuracy: 91.72% validation accuracy: 73.58%
# Epoch 107: loss on final training batch: 0.3736
# training accuracy: 91.05% validation accuracy: 72.24%
# Epoch 108: loss on final training batch: 0.4225
# training accuracy: 89.62% validation accuracy: 74.25%
# Epoch 109: loss on final training batch: 0.3490
# training accuracy: 91.17% validation accuracy: 73.24%
# Epoch 110: loss on final training batch: 0.3651
# training accuracy: 92.43% validation accuracy: 76.25%
# Epoch 111: loss on final training batch: 0.3474
# training accuracy: 93.14% validation accuracy: 75.92%
# Epoch 112: loss on final training batch: 0.3326
# training accuracy: 92.38% validation accuracy: 77.26%
# Epoch 113: loss on final training batch: 0.3219
# training accuracy: 91.88% validation accuracy: 75.59%
# Epoch 114: loss on final training batch: 0.3647
# training accuracy: 91.63% validation accuracy: 73.58%
# Epoch 115: loss on final training batch: 0.2578
# training accuracy: 93.81% validation accuracy: 76.59%
# Epoch 116: loss on final training batch: 0.2654
# training accuracy: 93.51% validation accuracy: 69.90%
# Epoch 117: loss on final training batch: 0.2629
# training accuracy: 94.69% validation accuracy: 72.91%
# Epoch 118: loss on final training batch: 0.2986
# training accuracy: 93.47% validation accuracy: 74.92%
# Epoch 119: loss on final training batch: 0.3204
# training accuracy: 92.93% validation accuracy: 72.24%
# Epoch 120: loss on final training batch: 0.3282
# training accuracy: 93.31% validation accuracy: 75.25%
# Epoch 121: loss on final training batch: 0.3079
# training accuracy: 92.64% validation accuracy: 72.24%
# Epoch 122: loss on final training batch: 0.2344
# training accuracy: 94.06% validation accuracy: 72.91%
# Epoch 123: loss on final training batch: 0.2498
# training accuracy: 94.14% validation accuracy: 72.91%
# Epoch 124: loss on final training batch: 0.3320
# training accuracy: 91.59% validation accuracy: 73.24%
# Epoch 125: loss on final training batch: 0.2838
# training accuracy: 93.26% validation accuracy: 74.58%
# Epoch 126: loss on final training batch: 0.2192
# training accuracy: 95.82% validation accuracy: 75.92%
# Epoch 127: loss on final training batch: 0.2149
# training accuracy: 95.86% validation accuracy: 76.25%
# Epoch 128: loss on final training batch: 0.2125
# training accuracy: 94.48% validation accuracy: 73.24%
# Epoch 129: loss on final training batch: 0.2440
# training accuracy: 93.43% validation accuracy: 73.58%
# Epoch 130: loss on final training batch: 0.2604
# training accuracy: 93.22% validation accuracy: 74.58%
# Epoch 131: loss on final training batch: 0.2759
# training accuracy: 92.64% validation accuracy: 70.90%
# Epoch 132: loss on final training batch: 0.4811
# training accuracy: 82.97% validation accuracy: 62.88%
# Epoch 133: loss on final training batch: 0.6310
# training accuracy: 83.93% validation accuracy: 71.57%
# Epoch 134: loss on final training batch: 0.5329
# training accuracy: 88.16% validation accuracy: 73.91%
# Epoch 135: loss on final training batch: 0.3362
# training accuracy: 92.43% validation accuracy: 75.25%
# Epoch 136: loss on final training batch: 0.2931
# training accuracy: 93.47% validation accuracy: 78.60%
# Epoch 137: loss on final training batch: 0.2973
# training accuracy: 93.51% validation accuracy: 77.59%
# Epoch 138: loss on final training batch: 0.2836
# training accuracy: 94.23% validation accuracy: 77.93%
# Epoch 139: loss on final training batch: 0.2631
# training accuracy: 94.27% validation accuracy: 77.26%
# Epoch 140: loss on final training batch: 0.1923
# training accuracy: 95.86% validation accuracy: 78.26%
# Epoch 141: loss on final training batch: 0.1768
# training accuracy: 97.03% validation accuracy: 77.93%
# Epoch 142: loss on final training batch: 0.2066
# training accuracy: 96.28% validation accuracy: 76.59%
# Epoch 143: loss on final training batch: 0.2623
# training accuracy: 94.94% validation accuracy: 77.26%
# Epoch 144: loss on final training batch: 0.3709
# training accuracy: 92.59% validation accuracy: 74.25%
# Epoch 145: loss on final training batch: 0.2785
# training accuracy: 93.60% validation accuracy: 74.58%
# Epoch 146: loss on final training batch: 0.3602
# training accuracy: 90.59% validation accuracy: 74.58%
# Epoch 147: loss on final training batch: 0.3714
# training accuracy: 93.10% validation accuracy: 76.92%
# Epoch 148: loss on final training batch: 0.2470
# training accuracy: 94.90% validation accuracy: 76.25%
# Epoch 149: loss on final training batch: 0.2481
# training accuracy: 94.77% validation accuracy: 76.25%
# Epoch 150: loss on final training batch: 0.2585
# training accuracy: 93.64% validation accuracy: 73.91%
# Epoch 151: loss on final training batch: 0.1568
# training accuracy: 96.65% validation accuracy: 76.92%
# Epoch 152: loss on final training batch: 0.1831
# training accuracy: 96.32% validation accuracy: 78.93%
# Epoch 153: loss on final training batch: 0.2058
# training accuracy: 95.65% validation accuracy: 77.93%
# Epoch 154: loss on final training batch: 0.1824
# training accuracy: 95.98% validation accuracy: 75.25%
# Epoch 155: loss on final training batch: 0.1596
# training accuracy: 96.99% validation accuracy: 76.92%
# Epoch 156: loss on final training batch: 0.1344
# training accuracy: 98.24% validation accuracy: 76.59%
# Epoch 157: loss on final training batch: 0.6326
# training accuracy: 83.39% validation accuracy: 69.23%
# Epoch 158: loss on final training batch: 0.7871
# training accuracy: 75.06% validation accuracy: 65.89%
# Epoch 159: loss on final training batch: 0.6207
# training accuracy: 81.05% validation accuracy: 70.57%
# Epoch 160: loss on final training batch: 0.5127
# training accuracy: 85.02% validation accuracy: 72.24%
# Epoch 161: loss on final training batch: 0.4004
# training accuracy: 86.69% validation accuracy: 73.91%
# Epoch 162: loss on final training batch: 0.3596
# training accuracy: 90.38% validation accuracy: 74.25%
# Epoch 163: loss on final training batch: 0.3534
# training accuracy: 90.67% validation accuracy: 73.58%
# Epoch 164: loss on final training batch: 0.3398
# training accuracy: 89.16% validation accuracy: 71.57%
# Epoch 165: loss on final training batch: 0.2876
# training accuracy: 90.46% validation accuracy: 73.91%
# Epoch 166: loss on final training batch: 0.3144
# training accuracy: 90.42% validation accuracy: 71.91%
# Epoch 167: loss on final training batch: 0.3087
# training accuracy: 89.75% validation accuracy: 69.57%
# Epoch 168: loss on final training batch: 0.2751
# training accuracy: 89.58% validation accuracy: 70.90%
# Epoch 169: loss on final training batch: 0.2227
# training accuracy: 91.67% validation accuracy: 71.91%
# Epoch 170: loss on final training batch: 0.2317
# training accuracy: 92.55% validation accuracy: 70.90%
# Epoch 171: loss on final training batch: 0.2175
# training accuracy: 94.90% validation accuracy: 74.92%
# Epoch 172: loss on final training batch: 0.3080
# training accuracy: 91.42% validation accuracy: 75.92%
# Epoch 173: loss on final training batch: 0.2982
# training accuracy: 90.67% validation accuracy: 75.59%
# Epoch 174: loss on final training batch: 0.2620
# training accuracy: 93.81% validation accuracy: 77.93%
# Epoch 175: loss on final training batch: 0.2202
# training accuracy: 94.56% validation accuracy: 76.25%
# Epoch 176: loss on final training batch: 0.2128
# training accuracy: 94.94% validation accuracy: 75.59%
# Epoch 177: loss on final training batch: 0.2673
# training accuracy: 93.05% validation accuracy: 75.92%
# Epoch 178: loss on final training batch: 0.3780
# training accuracy: 91.17% validation accuracy: 74.58%
# Epoch 179: loss on final training batch: 0.2347
# training accuracy: 94.27% validation accuracy: 75.59%
# Epoch 180: loss on final training batch: 0.2010
# training accuracy: 95.86% validation accuracy: 76.25%
# Epoch 181: loss on final training batch: 0.1866
# training accuracy: 97.15% validation accuracy: 74.25%
# Epoch 182: loss on final training batch: 0.1556
# training accuracy: 97.70% validation accuracy: 74.92%
# Epoch 183: loss on final training batch: 0.1266
# training accuracy: 98.08% validation accuracy: 74.58%
# Epoch 184: loss on final training batch: 0.1121
# training accuracy: 98.74% validation accuracy: 75.25%
# Epoch 185: loss on final training batch: 0.0978
# training accuracy: 99.00% validation accuracy: 76.59%
# Epoch 186: loss on final training batch: 0.0993
# training accuracy: 99.12% validation accuracy: 76.92%
# Epoch 187: loss on final training batch: 0.1013
# training accuracy: 99.33% validation accuracy: 78.60%
# Epoch 188: loss on final training batch: 0.0872
# training accuracy: 99.08% validation accuracy: 78.93%
# Epoch 189: loss on final training batch: 0.0969
# training accuracy: 98.91% validation accuracy: 76.59%
# Epoch 190: loss on final training batch: 0.0983
# training accuracy: 98.49% validation accuracy: 76.59%
# Epoch 191: loss on final training batch: 0.0855
# training accuracy: 99.12% validation accuracy: 74.58%
# Epoch 192: loss on final training batch: 0.0999
# training accuracy: 98.70% validation accuracy: 78.93%
# Epoch 193: loss on final training batch: 0.1197
# training accuracy: 98.41% validation accuracy: 76.92%
# Epoch 194: loss on final training batch: 0.0927
# training accuracy: 98.79% validation accuracy: 76.25%
# Epoch 195: loss on final training batch: 0.0843
# training accuracy: 99.67% validation accuracy: 75.59%
# Epoch 196: loss on final training batch: 0.0778
# training accuracy: 99.41% validation accuracy: 77.59%
# Epoch 197: loss on final training batch: 0.0736
# training accuracy: 98.58% validation accuracy: 76.25%
# Epoch 198: loss on final training batch: 0.1195
# training accuracy: 98.74% validation accuracy: 76.59%
# Epoch 199: loss on final training batch: 0.1044
# training accuracy: 98.91% validation accuracy: 73.91%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)

# %%
torch.save(model.state_dict(), saved_model_name)
