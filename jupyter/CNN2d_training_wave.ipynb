# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['opt',
#  'dev',
#  'run',
#  'etc',
#  'root',
#  'usr',
#  'boot',
#  'srv',
#  'sys',
#  'proc',
#  'var',
#  'home',
#  'tmp',
#  'lib64',
#  'mnt',
#  'media',
#  'lib',
#  'sbin',
#  'bin',
#  'content',
#  '.dockerenv',
#  'tools',
#  'datalab',
#  'tensorflow-1.15.2',
#  'python-apt',
#  'lib32']

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicCNN2d import MusicCNN2d
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([2390, 501, 40])
# torch.Size([2390])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[ 0.4324,  0.5236,  0.5394,  ...,  0.7697,  0.7055,  0.3866],
#         [ 0.7034,  0.6647,  0.4897,  ...,  0.4557,  0.3747,  0.2816],
#         [ 0.6879,  0.5071,  0.1787,  ...,  0.1181,  0.2188,  0.3338],
#         ...,
#         [ 0.9628,  0.9904,  0.9130,  ...,  0.3897,  0.3010,  0.0407],
#         [ 0.8118,  0.8570,  0.7527,  ...,  0.1811,  0.2039, -0.0195],
#         [ 0.4746,  0.5449,  0.4947,  ..., -0.2057, -0.4388, -0.4447]])
# tensor(0)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([299, 501, 40])
# torch.Size([299])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicCNN2d([8, 32, 64, 64], 3968, [600], 10)

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
X_a = X_train[:10].reshape((-1, 1, n_time, n_feat))
print(X_a.shape)
pred = model(X_a)
print(pred.shape)
# Out:
# torch.Size([10, 1, 501, 40])
# torch.Size([10, 10])

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 300
num_epoch = 30
weight_decay = 1e-5
model_name = 'CNN2d'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
X_train_2d = X_train.reshape((-1, 1, n_time, n_feat))
#print(X_train.shape)
X_val_2d = X_val.reshape((-1, 1, n_time, n_feat))
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train_2d, y_train, X_val_2d, y_val), 
                  loss, optimizer, batch_size = batch_size, num_epoch = num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 1.4879
# training accuracy: 54.48% validation accuracy: 49.16%
# Epoch  1: loss on final training batch: 1.0412
# training accuracy: 67.15% validation accuracy: 56.52%
# Epoch  2: loss on final training batch: 0.7528
# training accuracy: 77.07% validation accuracy: 61.20%
# Epoch  3: loss on final training batch: 0.5460
# training accuracy: 84.48% validation accuracy: 65.89%
# Epoch  4: loss on final training batch: 0.4752
# training accuracy: 87.28% validation accuracy: 65.22%
# Epoch  5: loss on final training batch: 0.2656
# training accuracy: 95.19% validation accuracy: 65.22%
# Epoch  6: loss on final training batch: 0.2037
# training accuracy: 96.23% validation accuracy: 69.23%
# Epoch  7: loss on final training batch: 0.1226
# training accuracy: 97.95% validation accuracy: 68.56%
# Epoch  8: loss on final training batch: 0.0796
# training accuracy: 99.41% validation accuracy: 69.90%
# Epoch  9: loss on final training batch: 0.0425
# training accuracy: 99.75% validation accuracy: 72.58%
# Epoch 10: loss on final training batch: 0.0489
# training accuracy: 99.58% validation accuracy: 70.90%
# Epoch 11: loss on final training batch: 0.0415
# training accuracy: 99.08% validation accuracy: 68.90%
# Epoch 12: loss on final training batch: 0.0257
# training accuracy: 99.50% validation accuracy: 71.24%
# Epoch 13: loss on final training batch: 0.0166
# training accuracy: 99.87% validation accuracy: 70.23%
# Epoch 14: loss on final training batch: 0.0280
# training accuracy: 99.46% validation accuracy: 70.23%
# Epoch 15: loss on final training batch: 0.0096
# training accuracy: 99.92% validation accuracy: 69.23%
# Epoch 16: loss on final training batch: 0.0077
# training accuracy: 99.92% validation accuracy: 70.57%
# Epoch 17: loss on final training batch: 0.0057
# training accuracy: 99.92% validation accuracy: 68.90%
# Epoch 18: loss on final training batch: 0.0046
# training accuracy: 99.92% validation accuracy: 69.57%
# Epoch 19: loss on final training batch: 0.0040
# training accuracy: 99.92% validation accuracy: 70.57%
# Epoch 20: loss on final training batch: 0.0036
# training accuracy: 99.92% validation accuracy: 70.90%
# Epoch 21: loss on final training batch: 0.0032
# training accuracy: 99.92% validation accuracy: 70.23%
# Epoch 22: loss on final training batch: 0.0030
# training accuracy: 99.92% validation accuracy: 70.57%
# Epoch 23: loss on final training batch: 0.0028
# training accuracy: 99.92% validation accuracy: 70.23%
# Epoch 24: loss on final training batch: 0.0026
# training accuracy: 99.92% validation accuracy: 69.90%
# Epoch 25: loss on final training batch: 0.0024
# training accuracy: 99.92% validation accuracy: 70.90%
# Epoch 26: loss on final training batch: 0.0023
# training accuracy: 99.92% validation accuracy: 70.57%
# Epoch 27: loss on final training batch: 0.0021
# training accuracy: 99.92% validation accuracy: 70.23%
# Epoch 28: loss on final training batch: 0.0020
# training accuracy: 99.92% validation accuracy: 70.57%
# Epoch 29: loss on final training batch: 0.0019
# training accuracy: 99.92% validation accuracy: 70.57%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array[10:], validation_loss_array[10:]], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
